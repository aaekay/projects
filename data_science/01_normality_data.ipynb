# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import shapiro

# %%
x = np.random.normal(size=300)
y = np.random.uniform(size = 300)
plt.hist(x)
plt.hist(y)
plt.show()

# %%
shapiro(x)
# Out:
# ShapiroResult(statistic=0.9984697699546814, pvalue=0.9957431554794312)

# %%
shapiro(y)
# Out:
# ShapiroResult(statistic=0.9497256278991699, pvalue=1.3020941658226093e-08)
